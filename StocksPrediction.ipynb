# %%
import io, time, os, os.path
import math,json, requests, urllib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
def getStocktwitsData (ticker, fromDate):
    response = requests.get('https://api.stocktwits.com/api/2/streams/symbol/%s.json' % (ticker))
    if response.status_code == 200:
        return json.loads(response.content)
    #status 429 means user has submitted too many requests
    elif response.status_code == 429:
        print response.content
        return None
    return None
response = getStocktwitsData('amd',1000)
print response
# Out:
# {u'cursor': {u'max': 85452634, u'since': 85454343, u'more': True}, u'symbol': {u'symbol': u'AMD', u'is_following': False, u'id': 4331, u'title': u'Advanced Micro Devices, Inc.'}, u'messages': [{u'body': u'$AMD Sitting 12 hours in chair watching AMD rise makes your arse hurt..guess not near the arse pain shorts are feeling tonight.25 minutes,', u'entities': {u'sentiment': {u'basic': u'Bullish'}}, u'reshares': {u'reshared_count': 0, u'user_ids': []}, u'created_at': u'2017-06-08T23:35:47Z', u'mentioned_users': [], u'symbols': [{u'symbol': u'AMD', u'is_following': False, u'id': 4331, u'title': u'Advanced Micro Devices, Inc.'}], u'source': {u'url': u'http://stocktwits.com', u'id': 1, u'title': u'StockTwits'}, u'user': {u'username': u'IgotthegoldrightherePa', u'name': u'IgotthegoldrightherePa', u'classification': [], u'official': False, u'join_date': u'2017-03-21', u'avatar_url': u'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg', u'avatar_url_ssl': u'https://s3.amazonaws.com
# ...
